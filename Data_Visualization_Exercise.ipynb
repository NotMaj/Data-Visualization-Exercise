# %% [markdown]
# <a href="https://colab.research.google.com/github/NotMaj/Data-Visualization-Exercise/blob/main/Data_Visualization_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filename ='/content/literacy_rates.csv'
df =pd.read_csv(filename)

# %%
df
# Out:
#                          Region      Country  Year    Age  Gender  \
# 0     Central and Southern Asia  Afghanistan  2011    15+  female
# 1     Central and Southern Asia  Afghanistan  2011    15+    male
# 2     Central and Southern Asia  Afghanistan  2011    15+   total
# 3                           NaN  Afghanistan  2011  15-24  female
# 4                           NaN  Afghanistan  2011  15-24    male
# ...                         ...          ...   ...    ...     ...
# 4950         Sub-Saharan Africa     Zimbabwe  2014  25-64    male
# 4951         Sub-Saharan Africa     Zimbabwe  2014  25-64   total
# 4952         Sub-Saharan Africa     Zimbabwe  2014    65+  female
# 4953         Sub-Saharan Africa     Zimbabwe  2014    65+    male
# 4954         Sub-Saharan Africa     Zimbabwe  2014    65+   total
#
#            Literacy rate
# 0              0.1761206
# 1               0.454171
# 2              0.3174112
# 3              0.3211322
# 4              0.6187907
# ...

# %%
#DATA CLEANING
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Region           5
# Country          0
# Year             0
# Age              0
# Gender           0
# Literacy rate    0
# dtype: int64

# %%
missing_value = df['Region'].isna()

# %%
df.loc[missing_value]
# Out:
#     Region      Country  Year    Age  Gender       Literacy rate
# 3      NaN  Afghanistan  2011  15-24  female           0.3211322
# 4      NaN  Afghanistan  2011  15-24    male           0.6187907
# 464    NaN   Uzbekistan  2016    65+  female  0.9966974999999999
# 465    NaN   Uzbekistan  2016    65+    male           0.9990176
# 466    NaN   Uzbekistan  2016    65+   total  0.9977187999999999

# %%
df[df['Country']== 'Uzbekistan']
# Out:
#                         Region     Country  Year    Age  Gender  \
# 419  Central and Southern Asia  Uzbekistan  2013    15+  female
# 420  Central and Southern Asia  Uzbekistan  2013    15+    male
# 421  Central and Southern Asia  Uzbekistan  2013    15+   total
# 422  Central and Southern Asia  Uzbekistan  2013  15-24  female
# 423  Central and Southern Asia  Uzbekistan  2013  15-24    male
# 424  Central and Southern Asia  Uzbekistan  2013  15-24   total
# 425  Central and Southern Asia  Uzbekistan  2013  25-64  female
# 426  Central and Southern Asia  Uzbekistan  2013  25-64    male
# 427  Central and Southern Asia  Uzbekistan  2013  25-64   total
# 428  Central and Southern Asia  Uzbekistan  2013    65+  female
# 429  Central and Southern Asia  Uzbekistan  2013    65+    male
# 430  Central and Southern Asia  Uzbekistan  2013    65+   total
# 431  Central and Southern Asia  Uzbekistan  2014    15+  female
# 432  Central and Southern Asia  Uzbekistan  2014    15+    male
# ...

# %%
#Since both missing valuesa are of same region
df['Region'].fillna('Central and Southern Asia', inplace=True)

# %%
df
# Out:
#                          Region      Country  Year    Age  Gender  \
# 0     Central and Southern Asia  Afghanistan  2011    15+  female
# 1     Central and Southern Asia  Afghanistan  2011    15+    male
# 2     Central and Southern Asia  Afghanistan  2011    15+   total
# 3     Central and Southern Asia  Afghanistan  2011  15-24  female
# 4     Central and Southern Asia  Afghanistan  2011  15-24    male
# ...                         ...          ...   ...    ...     ...
# 4950         Sub-Saharan Africa     Zimbabwe  2014  25-64    male
# 4951         Sub-Saharan Africa     Zimbabwe  2014  25-64   total
# 4952         Sub-Saharan Africa     Zimbabwe  2014    65+  female
# 4953         Sub-Saharan Africa     Zimbabwe  2014    65+    male
# 4954         Sub-Saharan Africa     Zimbabwe  2014    65+   total
#
#            Literacy rate
# 0              0.1761206
# 1               0.454171
# 2              0.3174112
# 3              0.3211322
# 4              0.6187907
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4955 entries, 0 to 4954
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Region         4955 non-null   object
#  1   Country        4955 non-null   object
#  2   Year           4955 non-null   int64
#  3   Age            4955 non-null   object
#  4   Gender         4955 non-null   object
#  5   Literacy rate  4955 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 232.4+ KB

# %%
#Literacy rate is not correct datatype
df['Literacy rate'] = pd.to_numeric(df['Literacy rate'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "45.384%"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-b7788a50b962> in <cell line: 2>()
#       1 #Literacy rate is not correct datatype
# ----> 2 df['Literacy rate'] = pd.to_numeric(df['Literacy rate'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     183         coerce_numeric = errors not in ("ignore", "raise")
#     184         try:
# --> 185             values, _ = lib.maybe_convert_numeric(
#     186                 values, set(), coerce_numeric=coerce_numeric
#     187             )
#
# ...

# %%
df['Literacy rate'].replace('45.384%','45.384', inplace =True)

# %%
#RUN AGAIN
df['Literacy rate'] = pd.to_numeric(df['Literacy rate'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4955 entries, 0 to 4954
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Region         4955 non-null   object
#  1   Country        4955 non-null   object
#  2   Year           4955 non-null   int64
#  3   Age            4955 non-null   object
#  4   Gender         4955 non-null   object
#  5   Literacy rate  4955 non-null   float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 232.4+ KB

# %%
#PYTHON VISUALIZATIONS
df['Country'].value_counts()
# Out:
# Mexico                 108
# Uruguay                108
# Brazil                 108
# Palestine               96
# Turkey                  96
#                       ...
# Trinidad and Tobago     12
# Greece                  12
# Estonia                 12
# Hungary                 12
# Antigua and Barbuda      6
# Name: Country, Length: 155, dtype: int64

# %%
#Histogram for Mexico Females and their literacy rates
gender = df['Gender'] == 'female'
country = df['Country'] =='Mexico'
new_df = df.loc[gender & country]

# %%
new_df
# Out:
#                                Region Country  Year    Age  Gender  \
# 2288  Latin America and the Caribbean  Mexico  2010    15+  female
# 2291  Latin America and the Caribbean  Mexico  2010  15-24  female
# 2294  Latin America and the Caribbean  Mexico  2010  25-64  female
# 2297  Latin America and the Caribbean  Mexico  2010    65+  female
# 2300  Latin America and the Caribbean  Mexico  2011    15+  female
# 2303  Latin America and the Caribbean  Mexico  2011  15-24  female
# 2306  Latin America and the Caribbean  Mexico  2011  25-64  female
# 2309  Latin America and the Caribbean  Mexico  2011    65+  female
# 2312  Latin America and the Caribbean  Mexico  2012    15+  female
# 2315  Latin America and the Caribbean  Mexico  2012  15-24  female
# 2318  Latin America and the Caribbean  Mexico  2012  25-64  female
# 2321  Latin America and the Caribbean  Mexico  2012    65+  female
# 2324  Latin America and the Caribbean  Mexico  2013    15+  female
# ...

# %%
sns.histplot(data = new_df, x='Literacy rate', color='lightblue', edgecolor ='black')
plt.title('Distribution of Literacy rates for Female Mexicans')
plt.axvline(df['Literacy rate'].median(),
             color='black',
             ls=':',
             label= f"Median is {round(df['Literacy rate'].median(),2)}")
plt.legend();

# %% [markdown]
# From the histogram, the female population of Mexico exhibits a constant high literacy rate as seen from the count of values closest to 1.

# %%
df
# Out:
#                          Region      Country  Year    Age  Gender  \
# 0     Central and Southern Asia  Afghanistan  2011    15+  female
# 1     Central and Southern Asia  Afghanistan  2011    15+    male
# 2     Central and Southern Asia  Afghanistan  2011    15+   total
# 3     Central and Southern Asia  Afghanistan  2011  15-24  female
# 4     Central and Southern Asia  Afghanistan  2011  15-24    male
# ...                         ...          ...   ...    ...     ...
# 4950         Sub-Saharan Africa     Zimbabwe  2014  25-64    male
# 4951         Sub-Saharan Africa     Zimbabwe  2014  25-64   total
# 4952         Sub-Saharan Africa     Zimbabwe  2014    65+  female
# 4953         Sub-Saharan Africa     Zimbabwe  2014    65+    male
# 4954         Sub-Saharan Africa     Zimbabwe  2014    65+   total
#
#       Literacy rate
# 0          0.176121
# 1          0.454171
# 2          0.317411
# 3          0.321132
# 4          0.618791
# ...             ...
# 4950       0.897255
# ...

# %%
df.loc[df['Literacy rate'] == 45.384]
# Out:
#                        Region      Country  Year    Age Gender  Literacy rate
# 18  Central and Southern Asia  Afghanistan  2018  25-64   male         45.384

# %%
# NO literacy rate of 45, its limit is until 1 only.
df.drop(index= 18, inplace=True)

# %%
#Count THE AGES whos literacy rate is > 0.90
df
# Out:
#                          Region      Country  Year    Age  Gender  \
# 0     Central and Southern Asia  Afghanistan  2011    15+  female
# 1     Central and Southern Asia  Afghanistan  2011    15+    male
# 2     Central and Southern Asia  Afghanistan  2011    15+   total
# 3     Central and Southern Asia  Afghanistan  2011  15-24  female
# 4     Central and Southern Asia  Afghanistan  2011  15-24    male
# ...                         ...          ...   ...    ...     ...
# 4950         Sub-Saharan Africa     Zimbabwe  2014  25-64    male
# 4951         Sub-Saharan Africa     Zimbabwe  2014  25-64   total
# 4952         Sub-Saharan Africa     Zimbabwe  2014    65+  female
# 4953         Sub-Saharan Africa     Zimbabwe  2014    65+    male
# 4954         Sub-Saharan Africa     Zimbabwe  2014    65+   total
#
#       Literacy rate
# 0          0.176121
# 1          0.454171
# 2          0.317411
# 3          0.321132
# 4          0.618791
# ...             ...
# 4950       0.897255
# ...

# %%
graph_2 = df[df['Literacy rate'] >0.90]

# %%
graph_2
# Out:
#                          Region     Country  Year    Age  Gender  \
# 86    Central and Southern Asia  Bangladesh  2016  15-24  female
# 87    Central and Southern Asia  Bangladesh  2016  15-24    male
# 88    Central and Southern Asia  Bangladesh  2016  15-24   total
# 98    Central and Southern Asia  Bangladesh  2017  15-24  female
# 99    Central and Southern Asia  Bangladesh  2017  15-24    male
# ...                         ...         ...   ...    ...     ...
# 4934         Sub-Saharan Africa    Zimbabwe  2011  15-24  female
# 4936         Sub-Saharan Africa    Zimbabwe  2011  15-24   total
# 4946         Sub-Saharan Africa    Zimbabwe  2014  15-24  female
# 4948         Sub-Saharan Africa    Zimbabwe  2014  15-24   total
# 4953         Sub-Saharan Africa    Zimbabwe  2014    65+    male
#
#       Literacy rate
# 86         0.935353
# 87         0.909053
# 88         0.922427
# 98         0.943778
# 99         0.915413
# ...             ...
# 4934       0.921246
# ...

# %%
# Get the total Gender only
graph_2 = graph_2[graph_2['Gender'] == 'total']

# %%
graph_2
# Out:
#                          Region     Country  Year    Age Gender  Literacy rate
# 88    Central and Southern Asia  Bangladesh  2016  15-24  total       0.922427
# 100   Central and Southern Asia  Bangladesh  2017  15-24  total       0.929508
# 112   Central and Southern Asia  Bangladesh  2018  15-24  total       0.932964
# 136   Central and Southern Asia      Bhutan  2017  15-24  total       0.930906
# 160   Central and Southern Asia       India  2018  15-24  total       0.916640
# ...                         ...         ...   ...    ...    ...            ...
# 4792         Sub-Saharan Africa   Swaziland  2010  15-24  total       0.935023
# 4804         Sub-Saharan Africa   Swaziland  2018  15-24  total       0.954694
# 4924         Sub-Saharan Africa      Zambia  2018  15-24  total       0.920916
# 4936         Sub-Saharan Africa    Zimbabwe  2011  15-24  total       0.909307
# 4948         Sub-Saharan Africa    Zimbabwe  2014  15-24  total       0.904281
#
# [933 rows x 6 columns]

# %%
sns.countplot(data = graph_2, x='Age')
plt.title('Frequency of Ages with Literacy rate > 0.90');
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %% [markdown]
# This graph shows how ages 15-24 are the ones with literacy rates greater than 0.90. Additionally,ages 65+ has the least reported literacy rates which could mean that as people age their literacy rates decrease.

# %%
#MULTIVARIATE
df
# Out:
#                          Region      Country  Year    Age  Gender  \
# 0     Central and Southern Asia  Afghanistan  2011    15+  female
# 1     Central and Southern Asia  Afghanistan  2011    15+    male
# 2     Central and Southern Asia  Afghanistan  2011    15+   total
# 3     Central and Southern Asia  Afghanistan  2011  15-24  female
# 4     Central and Southern Asia  Afghanistan  2011  15-24    male
# ...                         ...          ...   ...    ...     ...
# 4950         Sub-Saharan Africa     Zimbabwe  2014  25-64    male
# 4951         Sub-Saharan Africa     Zimbabwe  2014  25-64   total
# 4952         Sub-Saharan Africa     Zimbabwe  2014    65+  female
# 4953         Sub-Saharan Africa     Zimbabwe  2014    65+    male
# 4954         Sub-Saharan Africa     Zimbabwe  2014    65+   total
#
#       Literacy rate
# 0          0.176121
# 1          0.454171
# 2          0.317411
# 3          0.321132
# 4          0.618791
# ...             ...
# 4950       0.897255
# ...

# %%
corr = df.corr()
sns.heatmap(corr, cmap='coolwarm', annot=True, fmt='.2f');
# Out:
# <ipython-input-47-b001a7d6990a>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()

# %% [markdown]
# From the heatmap, it can be said that the variables have no correlation with each other.

# %%
df_2=df[['Year','Literacy rate']]
df_2
# Out:
#       Year  Literacy rate
# 0     2011       0.176121
# 1     2011       0.454171
# 2     2011       0.317411
# 3     2011       0.321132
# 4     2011       0.618791
# ...    ...            ...
# 4950  2014       0.897255
# 4951  2014       0.887874
# 4952  2014       0.734258
# 4953  2014       0.927231
# 4954  2014       0.811269
#
# [4954 rows x 2 columns]

# %%
grouped = df_2.groupby(['Year'])['Literacy rate'].nunique()

# %%
grouped
# Out:
# Year
# 2010    598
# 2011    682
# 2012    516
# 2013    391
# 2014    598
# 2015    469
# 2016    391
# 2017    369
# 2018    855
# Name: Literacy rate, dtype: int64

# %%
years = list(grouped.index)

years
# Out:
# [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]

# %%
rates = list(grouped.values)
rates
# Out:
# [598, 682, 516, 391, 598, 469, 391, 369, 855]

# %%
plt.style.use('seaborn')
plt.plot(years,rates, marker='o', markersize = 10)
plt.title('Reported literacy rates throughout the years')
plt.xlabel('DATES')
plt.ylabel('Reported Literacy rates');
# Out:
# <ipython-input-85-2fedbb8aa795>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# From this graph, we can see how the data of reported literacy rates varies greatly, which can affect how the study of improvement or decline with literacy rates in certain countries.
